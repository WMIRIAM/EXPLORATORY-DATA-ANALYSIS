# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\ADMIN\Documents\Copy of US Superstore data.xls')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe().round()
# Out:
#        Row ID  Postal Code    Sales  Quantity  Discount  Profit
# count  9994.0       9994.0   9994.0    9994.0    9994.0  9994.0
# mean   4998.0      55190.0    230.0       4.0       0.0    29.0
# std    2885.0      32064.0    623.0       2.0       0.0   234.0
# min       1.0       1040.0      0.0       1.0       0.0 -6600.0
# 25%    2499.0      23223.0     17.0       2.0       0.0     2.0
# 50%    4998.0      56430.0     54.0       3.0       0.0     9.0
# 75%    7496.0      90008.0    210.0       5.0       0.0    29.0
# max    9994.0      99301.0  22638.0      14.0       1.0  8400.0

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df=df.drop('Row ID', axis=1)
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
#how many countries are repsresented in the data
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
#drop the countries column as the data relates to the US only
df=df.drop('Country', axis=1)
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# PRODUCT LEVEL ANALYSIS

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Sub-Category'].nunique()
# Out:
# 17

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
#no of products available in the store
df['Product Name'].nunique()
# Out:
# 1850

# %%
#how much of each product has been sold from the store?
df['Product Name'].value_counts()
# Out:
# Staple envelope                                                        48
# Staples                                                                46
# Easy-staple paper                                                      46
# Avery Non-Stick Binders                                                20
# Staples in misc. colors                                                19
#                                                                        ..
# Hewlett-Packard Desktjet 6988DT Refurbished Printer                     1
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream     1
# Cubify CubeX 3D Printer Triple Head Print                               1
# Xerox 1926                                                              1
# Eldon Jumbo ProFile Portable File Boxes Graphite/Black                  1
# Name: Product Name, Length: 1850, dtype: int64

# %%
#showing the sales on a chart
plt.figure(figsize=(12, 10))
df['Sub-Category'].value_counts().plot.pie(autopct='%2.1f%%')
plt.show()

# %%
#profit earned per sub-category
#sales per sub-category
df.groupby('Sub-Category')['Profit'].sum().plot.bar()
plt.title('PROFITS BY SUB-CATEGORY')
plt.show()

# %%
#Copiers lead in profits earned while tables and bookcases are in losses.

# %%
#what are the top 10 products in sales.
plt.figure(figsize=(12, 10))
df['Product Name'].value_counts().head(10).plot.pie(autopct='%2.2f%%')
plt.show()

# %%
#sub-category popularity based on region
plt.figure(figsize= (20, 8))
sns.countplot(x='Sub-Category', hue='Region', data=df)
plt.title('Sub-category popularity regionwise')
plt.show()

# %%
#from the table, the western region is leading in orders in almost all subcategories.as such, people from the wetsern region order more from the store.

# %%
#to better understand the store preformance, i will calculate the profit base margin for the sub-categories
df.head(5)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df['Cost']=df['Sales']- df['Profit']

# %%
df['Profitbasemargin']=(df['Profit']/ df['Cost'])*100
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  ...  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420  ...
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420  ...
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036  ...
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311  ...
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#top 10 products wrt to profitbase margin
df.sort_values(['Profitbasemargin', 'Product Name'], ascending=False).groupby('Profitbasemargin').head(10)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1696  CA-2015-156335 2015-09-25 2015-09-28    Second Class    PO-19195
# 4611  CA-2016-109407 2016-01-24 2016-01-26    Second Class    HG-14965
# 3984  CA-2016-135265 2016-07-07 2016-07-09    Second Class    CC-12370
# 4651  CA-2017-150987 2017-04-08 2017-04-12  Standard Class    AH-10120
# 6600  CA-2014-154095 2014-12-02 2014-12-07  Standard Class    ON-18715
# ...              ...        ...        ...             ...         ...
# 4437  CA-2016-163398 2016-05-03 2016-05-08  Standard Class    CB-12415
# 8766  CA-2015-107083 2015-11-21 2015-11-27  Standard Class    BB-11545
# 676   US-2017-119438 2017-03-18 2017-03-23  Standard Class    CD-11980
# 261   US-2017-155299 2017-06-08 2017-06-12  Standard Class    Dl-13600
# 9164  CA-2015-164007 2015-06-08 2015-06-12  Standard Class    MG-17695
#
#            Customer Name      Segment           City        State  \
# ...

# %% [markdown]
# retailers that sold phones, binders paper had percent profit.

# %% [markdown]
# CUSTOMER LEVEL ANALYSIS

# %%
#number of customers that purchased from the store
df['Customer ID'].nunique()
# Out:
# 793

# %%
#top 10 customers ordering from the store
df_top10=df['Customer Name'].value_counts().head(10)
df_top10
# Out:
# William Brown          37
# Matt Abelman           34
# Paul Prost             34
# John Lee               34
# Chloris Kastensmidt    32
# Seth Vernon            32
# Jonathan Doherty       32
# Edward Hooks           32
# Arthur Prichep         31
# Emily Phan             31
# Name: Customer Name, dtype: int64

# %%
#segment leading in purchases
plt.figure(figsize=(15, 8))
sns.countplot(x='Segment', hue='Region', data=df)
plt.title('segment orders by region')
plt.ylabel('Number of orders')
plt.show()

# %% [markdown]
# the consumer segment leads in the number of purchases, followed by the corporate and the home office segments respectively.

# %%
#top 20 customers who benefitted the store. These are the customers from who the store generated the highest profits. 
top20=df.sort_values('Profit', ascending=False).head(20)
fig=plt.figure(figsize=(20, 8))
ax=fig.add_subplot(111)
sns.barplot(x='Customer Name', y='Profit', palette='Set1', data=top20, ax=ax)
plt.title('Top twenty customers in profit')
plt.tight_layout()
plt.show()

# %%
#top 20 customers who benefitted the store and by state

top20=df.sort_values('Profit', ascending=False).head(20)
fig=plt.figure(figsize=(20, 8))
ax=fig.add_subplot(111)
sns.barplot(x='Customer Name', y='Profit', hue='State', palette='Set1', data=top20, ax=ax)
plt.title('Top twenty customers in profit by State')
plt.tight_layout()
plt.show()
#Majority of the profitable customers come from the newyork and michigan states.
